# %%
from pytubefix import YouTube

# %%
v_url = 'https://www.youtube.com/watch?v=WA9gVKKPsBo'
# v_url = "https://www.youtube.com/watch?v=NHN1bdtFKKA"
# v_url = "https://www.youtube.com/watch?v=zChbwWF7e9k"
# v_url = "https://www.youtube.com/watch?v=E5S-U5mSyK4"

# v_url = "https://www.youtube.com/watch?v=AlJEpbaNYt0"

yt = YouTube(v_url)
# yt.bypass_age_gate()

print(yt.vid_info)

print(yt.title)

print(yt.caption_tracks)
# Out:
# {'responseContext': {'visitorData': 'CgtraXhXb1VRWUJDcyiSieG1BjIKCgJVUxIEGgAgMw%3D%3D', 'maxAgeSeconds': 0}, 'playabilityStatus': {'status': 'OK', 'playableInEmbed': True}, 'streamingData': {'expiresInSeconds': '21540', 'formats': [{'itag': 18, 'url': 'https://rr1---sn-qxoednee.googlevideo.com/videoplayback?expire=1723373810&ei=kkS4ZoOqE8uosfIP-5WV2AY&ip=35.233.214.201&id=o-AGL0-4zD4oVk9QuWcRzmlBF7kMW36eP_3qLt7ZUft42D&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=Uj&mm=31%2C29&mn=sn-qxoednee%2Csn-qxo7rn7k&ms=au%2Crdu&mv=m&mvi=1&pl=17&initcwndbps=2670000&vprv=1&svpuc=1&mime=video%2Fmp4&rqh=1&gir=yes&clen=459306530&ratebypass=yes&dur=9979.727&lmt=1721808529192247&mt=1723351736&fvip=3&c=ANDROID_TESTSUITE&txp=5538434&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Crqh%2Cgir%2Cclen%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIhAMz3-RXFKe-GiMMaYb6mJAysO56W3bS4qsHPapOdNEWIAiBSFjWtvs3nqvP7o9iuw6YU9Wmze4MLb4LXwxKzlcLQDA%3D%3D&lsparams=mh%2Cm
# ...

# %%
import main

print(yt.streams) # .filter(progressive=True))

main.preferred_resolution(yt)
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="248" mime_type="video/webm" res="1080p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="399" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="av01.0.08M.08" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="398" mime_type="video/mp4" res="720p" fps="30fps" vcodec="av01.0.05M.08" progressive="False" type="video">, <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="244"
# ...

# %%
name = "Prompt Poet - Character AI's Prompting Framework"
import re
file_name = re.sub(r"[^a-zA-Z0-9_]", "_", name.lower().replace(" ", "_"))
print(file_name)
# Out:
# prompt_poet___character_ai_s_prompting_framework
